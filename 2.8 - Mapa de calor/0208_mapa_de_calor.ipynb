# %% [markdown]
# > Este notebook é parte do material didático do curso "Visualização de dados com Python" do LinkedIn Learning

# %% [markdown]
# # Mapa de calor
# Aprenda a construir mapas de calor com Matplotlib e Seaborn. Utilizando um conjunto de dados do SUS, modificado para fins didáticos, sobre internações hospitalares em Rondônia no ano de 2023.
#
#
# Fonte original dos dados: [Base dos dados](https://basedosdados.org/dataset/ff933265-8b61-4458-877a-173b3f38102b?table=75db9d44-42be-42c5-9fbc-7591f4dc8d5f)

# %% [markdown]
# ## Visualização de mudança ao longo do tempo

# %%
# Importa bibliotecas

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importa os dados para dataframe

df_sus_bruto = pd.read_csv('/content/0208_mapa_de_calor.csv', dtype={'mes': int, 'id_municipio_paciente': int, 'custo_tratamento': int})

# %%
df_sus_bruto.head()
# Out:
#    Unnamed: 0 sigla_uf  mes_internacao  id_municipio_paciente  \
# 0           0       RO               5                 110009
# 1           1       RO               5                 110009
# 2           2       RO               5                 110009
# 3           3       RO               5                 110009
# 4           4       RO               5                 110014
#
#          municipio_paciente  custo_tratamento
# 0           Espigão D'Oeste            306434
# 1           Espigão D'Oeste            346966
# 2           Espigão D'Oeste             32081
# 3           Espigão D'Oeste            184849
# 4  Nova Brasilândia D'Oeste            386534

# %%
# Cria dataframe com total de internações por município e por mês

df_sus_agrupado = df_sus_bruto[['mes_internacao', 'municipio_paciente']].groupby(['mes_internacao', 'municipio_paciente'], as_index=False).value_counts()

# %%
df_sus_agrupado.head()
# Out:
#    mes_internacao       municipio_paciente  count
# 0               1    Alta Floresta D'Oeste   1473
# 1               1  Alto Alegre dos Parecis    414
# 2               1             Alto Paraíso    807
# 3               1         Alvorada D'Oeste    259
# 4               1                Ariquemes   5876

# %%
# Ajusta layout do dataframe para visualização

df_sus_sumarizado = pd.pivot_table(df_sus_agrupado, values='count', index=['mes_internacao'], columns=['municipio_paciente'], aggfunc='sum')

# %%
df_sus_sumarizado.head()
# Out:
# municipio_paciente  Alta Floresta D'Oeste  Alto Alegre dos Parecis  \
# mes_internacao
# 1                                    1473                      414
# 2                                    1245                      735
# 3                                    2123                      694
# 4                                    1892                      592
# 5                                    1787                     1099
#
# municipio_paciente  Alto Paraíso  Alvorada D'Oeste  Ariquemes  Buritis  \
# mes_internacao
# 1                            807               259       5876     1582
# 2                            415               570       5019     1287
# 3                            722               910       6887     1164
# 4                            438               509       6690     1666
# 5                            957               821       7331     2789
#
# municipio_paciente  Cabixi  Cacaulândia  Cacoal  Campo Novo de Rondônia  ...  \
# mes_internacao                                                           ...
# 1                      339          205    6202                     234  ...
# 2                      349          124    5458                     411  ...
# 3                      356          270    9368                     371  ...
# 4                      422          328    9614                     535  ...
# 5                      402          307   11016                     796  ...
#
# municipio_paciente  Seringueiras  São Felipe D'Oeste  \
# mes_internacao
# 1                            477                 258
# 2                            646                 296
# 3                            703                 281
# 4                            835                 281
# 5                           1031                 276
#
# municipio_paciente  São Francisco do Guaporé  São Miguel do Guaporé  \
# mes_internacao
# 1                                        923                   1086
# 2                                        584                   1194
# 3                                        896                   1036
# 4                                        911                   1319
# 5                                       1563                   1398
#
# municipio_paciente  Teixeirópolis  Theobroma  Urupá  Vale do Anari  \
# mes_internacao
# 1                              93        236    551            218
# 2                              41        168    469            572
# 3                              30        232    699            257
# 4                              46        150    616            390
# 5                              92        513    552            412
#
# municipio_paciente  Vale do Paraíso  Vilhena
# mes_internacao
# 1                               123     8643
# 2                               170     8546
# 3                               404     7836
# 4                               143    10540
# 5                               415     9698
#
# [5 rows x 52 columns]

# %%
# Cria visualização

sns.heatmap(df_sus_sumarizado)

plt.show()

# %% [markdown]
# ## Customização

# %% [markdown]
# ### Título

# %%
sns.heatmap(df_sus_sumarizado)

plt.title('Total de internações no estado de Rondônia em 2023 - jan./out.')

plt.show()

# %% [markdown]
# ### Cor

# %%
sns.heatmap(df_sus_sumarizado,
            cmap='coolwarm')

plt.title('Total de internações no estado de Rondônia em 2023 - jan./out.')

plt.show()

# %% [markdown]
# ### Tamanho do gráfico

# %%
plt.figure(figsize=(25,6))

sns.heatmap(df_sus_sumarizado,
            cmap='coolwarm')

plt.title('Total de internações no estado de Rondônia em 2023 - jan./out.')

plt.show()

# %% [markdown]
# ### Fonte

# %%
plt.figure(figsize=(25,6))
sns.set(font_scale=0.9)

sns.heatmap(df_sus_sumarizado,
            cmap='coolwarm')

plt.title('Total de internações no estado de Rondônia em 2023 - jan./out.')

plt.show()

# %% [markdown]
# ### Grades

# %%
plt.figure(figsize=(25,6))
sns.set(font_scale=0.9)

sns.heatmap(df_sus_sumarizado,
            cmap='coolwarm',
            linewidth=0.2)

plt.title('Total de internações no estado de Rondônia em 2023 - jan./out.')

plt.show()

# %% [markdown]
# ## Visualização de correlação entre variáveis

# %%
df_sus_bruto.head()
# Out:
#    Unnamed: 0 sigla_uf  mes_internacao  id_municipio_paciente  \
# 0           0       RO               5                 110009
# 1           1       RO               5                 110009
# 2           2       RO               5                 110009
# 3           3       RO               5                 110009
# 4           4       RO               5                 110014
#
#          municipio_paciente  custo_tratamento
# 0           Espigão D'Oeste            306434
# 1           Espigão D'Oeste            346966
# 2           Espigão D'Oeste             32081
# 3           Espigão D'Oeste            184849
# 4  Nova Brasilândia D'Oeste            386534

# %%
df_sus_correlacao = df_sus_bruto[['mes_internacao', 'id_municipio_paciente', 'custo_tratamento']]

# %%
matrix_correlacao = df_sus_correlacao.corr()

# %%
matrix_correlacao
# Out:
#                        mes_internacao  id_municipio_paciente  custo_tratamento
# mes_internacao               1.000000               0.011209          0.000623
# id_municipio_paciente        0.011209               1.000000          0.001516
# custo_tratamento             0.000623               0.001516          1.000000

# %%
plt.figure(figsize=(5,3))

sns.heatmap(matrix_correlacao,
            cmap='rocket',
            annot=True) # Insere anotação
# Out:
# <Axes: >
